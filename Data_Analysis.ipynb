# %%
# Import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from pathlib import Path
from IPython.display import display
import os

# %%
# Step 1: Unzip the files
# Unzip file
file_path = "./data_v3.zip"
output_folder= Path("")
# !unzip {file_path} -d {output_folder}
# Out:
# Archive:  /Users/gauri1399/Desktop/Northwestern/Final/data_v3.zip
#  extracting: ./data_v3/antibodies.csv
#  extracting: ./data_v3/bal.csv
#  extracting: ./data_v3/demographics.csv
#  extracting: ./data_v3/lab_report.csv
#  extracting: ./data_v3/libraries.csv
#  extracting: ./data_v3/medications.csv
#  extracting: ./data_v3/mrss.csv
#  extracting: ./data_v3/pft.csv
#  extracting: ./data_v3/skin_biopsies.csv
#  extracting: ./data_v3/ssc_subtype.csv
#  extracting: ./data_v3/vitals.csv

# %%
# Step 2: Store Datasets as a dictionary

# Path to folder containing CSV files
data_folder = Path("./data_v3/")

# Store datasets
datasets = {}

# Function to clean column names
def clean_columns(df):
    df.columns = (
        df.columns
        .astype(str)
        .str.strip()
        .str.lower()
        .str.replace(r"[^\w]+", "_", regex=True)
        .str.replace(r"_+", "_", regex=True)
        .str.strip("_")
    )
    return df

ID_CANDIDATES = [
    "reg_id",
    "case_number",
    "study_code",
    "patient_id",
    "subject_id",
    "participant_id",
    "case_id",
    "record_id",
]

DATE_CANDIDATES = [
    "date_recorded",
    "date",
    "visit_date",
    "collection_date",
    "record_date",
    "test_date",
    "assessment_date",
    "sample_date",
    "pft_dts",
    "dts",
    "procedure_date",
    "order_date",
    "processing_date",
    "biopsy_date",
]


def find_id_col(df, extra_candidates=None):
    for c in (extra_candidates or []) + ID_CANDIDATES:
        if c in df.columns:
            return c
    raise KeyError(f"No id column found among candidates. Columns present: {list(df.columns)}")


def find_date_col(df, extra_candidates=None):
    for c in (extra_candidates or []) + DATE_CANDIDATES:
        if c in df.columns:
            return c
    raise KeyError(f"No date column found among candidates. Columns present: {list(df.columns)}")

# %%
#Step 3: Print a per-column data-quality summary

column_info = None

# Read and process each CSV
for file in data_folder.glob("*.csv"):

    name = file.stem

    # Read CSV
    df = pd.read_csv(file)

    # Clean columns
    df = clean_columns(df)

    # Store dataframe
    datasets[name] = df

    print("=" * 80)
    print(f"Dataset: {name}")
    print(f"Rows: {df.shape[0]:,}")
    print(f"Columns: {df.shape[1]}")

    # Create column summary table
    column_info = pd.DataFrame({
        "Column": df.columns,
        "Data Type": df.dtypes.astype(str).values,
        "Missing Values": df.isna().sum().values,
        "Duplicate Values": [
          df[col].duplicated().sum()
          for col in df.columns
      ],
        "Duplicate (%)": [
        round((df[col].duplicated().sum() / len(df)) * 100, 2)
        for col in df.columns
    ]
  })
    display(column_info)
# Out:
# ================================================================================
# Dataset: medications
# Rows: 3,273
# Columns: 4
#        Column Data Type  Missing Values  Duplicate Values  Duplicate (%)
# 0      reg_id    object               0              1946          59.46
# 1        date    object              35              1266          38.68
# 2  medication    object              20              3256          99.48
# 3        dose    object              85              3249          99.27
# ================================================================================
# Dataset: antibodies
# Rows: 3,511
# Columns: 4
#         Column Data Type  Missing Values  Duplicate Values  Duplicate (%)
# 0  case_number    object               0              2080          59.24
# 1          dts    object               0              1558          44.37
# 2         test    object               0              3508          99.91
# 3        value    object               0              3507          99.89
# ================================================================================
# Dataset: ssc_subtype
# Rows: 1,500
# Columns: 7
#             Column Data Type  Missing Values  Duplicate Values  Duplicate (%)
# 0       study_code    object               0                 0           0.00
# 1      ssc_subtype    object               0              1498          99.87
# 2         other_dx    object             555              1492          99.47
# 3     raynaud_date    object               0               256          17.07
# 4  nonraynaud_date    object               0               314          20.93
# 5    nonraynaud_sx    object               0              1495          99.67
# 6   diagnosis_date    object               0               355          23.67
# ================================================================================
# Dataset: mrss
# Rows: 3,113
# Columns: 4
#             Column Data Type  Missing Values  Duplicate Values  Duplicate (%)
# 0           reg_id    object               0              2289          73.53
# 1             date    object               0              1190          38.23
# 2  entry_user_name    object               0              3089          99.23
# 3       mrss_score     int64               0              3073          98.72
# ================================================================================
# Dataset: lab_report
# Rows: 30,941
# Columns: 4
#            Column Data Type  Missing Values  Duplicate Values  Duplicate (%)
# 0          reg_id    object               0             29628          95.76
# 1      order_date    object               5             28923          93.48
# 2  component_name    object               0             30921          99.94
# 3           value    object             588             28988          93.69
# ================================================================================
# Dataset: skin_biopsies
# Rows: 215
# Columns: 8
#                 Column Data Type  Missing Values  Duplicate Values  \
# 0          case_number    object               0                65
# 1          biopsy_date    object               0                 6
# 2      entry_user_name    object               0               196
# 3          biopsy_site    object               0               206
# 4  clinical_indication    object               0               210
# 5   specimen_accession    object               0                 0
# 6      image_file_path    object               0                 0
# 7         image_format    object               0               213
#
#    Duplicate (%)
# 0          30.23
# 1           2.79
# 2          91.16
# 3          95.81
# 4          97.67
# 5           0.00
# 6           0.00
# 7          99.07
# ================================================================================
# Dataset: libraries
# Rows: 918
# Columns: 24
#                                  Column Data Type  Missing Values  \
# 0                                reg_id    object               0
# 1                        cell_viability   float64              78
# 2                       processing_date    object             546
# 3                               comment    object             740
# 4                     rna_isolation_kit    object             647
# 5                        kit_lot_number   float64             647
# 6                        elution_vol_ul   float64             647
# 7                macrophage_rna_tube_id   float64             671
# 8   macrophage_rna_tube_location_box_id    object             671
# 9                        date_of_rna_qc    object             725
# 10                    rna_volume_for_qc   float64             725
# 11                                  rin   float64             786
# 12              rna_concentration_pg_ul   float64             686
# 13                           ts_comment    object             766
# 14                     techcore_comment    object             727
# 15                             sequence    object             648
# 16               tapestation_assay_type    object             726
# 17                        ul_for_250_pg   float64             726
# 18                             complete    object             726
# 19                    library_prep_date    object             726
# 20                               sample    object             611
# 21                          rna_tube_id   float64             671
# 22                   library_prep_plate    object             726
# 23                         rnaseq_batch    object             726
#
#     Duplicate Values  Duplicate (%)
# 0                216          23.53
# 1                454          49.46
# 2                574          62.53
# 3                906          98.69
# 4                914          99.56
# 5                909          99.02
# 6                912          99.35
# 7                670          72.98
# 8                909          99.02
# 9                731          79.63
# 10               914          99.56
# 11               876          95.42
# 12               685          74.62
# 13               912          99.35
# 14               911          99.24
# 15               915          99.67
# 16               914          99.56
# 17               747          81.37
# 18               915          99.67
# 19               731          79.63
# 20               614          66.88
# 21               670          72.98
# 22               907          98.80
# 23               909          99.02
# ================================================================================
# Dataset: vitals
# Rows: 40,250
# Columns: 4
#                      Column Data Type  Missing Values  Duplicate Values  \
# 0                    reg_id    object               0             38747
# 1                      date    object               0             37203
# 2  vital_type_name_category    object               0             40245
# 3               vital_value   float64               0             38767
#
#    Duplicate (%)
# 0          96.27
# 1          92.43
# 2          99.99
# 3          96.32
# ================================================================================
# Dataset: pft
# Rows: 5,069
# Columns: 5
#         Column Data Type  Missing Values  Duplicate Values  Duplicate (%)
# 0  case_number    object               0              3895          76.84
# 1      pft_dts    object               0              3861          76.17
# 2  description    object               0              5066          99.94
# 3         name    object               0              5066          99.94
# 4    ord_value   float64             794              4320          85.22
# ================================================================================
# Dataset: demographics
# Rows: 1,500
# Columns: 12
#          Column Data Type  Missing Values  Duplicate Values  Duplicate (%)
# 0         study    object               0              1499          99.93
# 1   case_number    object               0                 0           0.00
# 2    first_name    object               0              1157          77.13
# 3     last_name    object               0              1188          79.20
# 4    birth_date    object               0                66           4.40
# 5     ethnicity    object               0              1498          99.87
# 6        gender    object               0              1498          99.87
# 7         races    object               0              1496          99.73
# 8     diagnosis    object               0              1499          99.93
# 9         state    object               0              1492          99.47
# 10       height   float64               0              1140          76.00
# 11       weight   float64               0               617          41.13
# ================================================================================
# Dataset: bal
# Rows: 1,170
# Columns: 7
#                 Column Data Type  Missing Values  Duplicate Values  \
# 0               bal_id    object               0                 0
# 1               reg_id    object               0               350
# 2       procedure_date    object               0               247
# 3       procedure_site    object               0              1165
# 4  volume_instilled_ml     int64               0              1166
# 5  volume_recovered_ml   float64               0               696
# 6          bal_comment    object             372              1163
#
#    Duplicate (%)
# 0           0.00
# 1          29.91
# 2          21.11
# 3          99.57
# 4          99.66
# 5          59.49
# 6          99.40

# %%
# # Step 4: Change to common identifier and date column names

# # Rename matching columns to common names
for name, df in datasets.items():
    rename_dict = {}

    # Rename identifier column
    for col in df.columns:
        if col.lower() in ID_CANDIDATES:
            rename_dict[col] = "reg_id"

    # Rename date column
    for col in df.columns:
        if col.lower() in DATE_CANDIDATES:
            rename_dict[col] = "date_recorded"

    # Apply renaming
    if rename_dict:
        df.rename(columns=rename_dict, inplace=True)
        print(f"{name}: {rename_dict}")
# Out:
# medications: {'reg_id': 'reg_id', 'date': 'date_recorded'}
# antibodies: {'case_number': 'reg_id', 'dts': 'date_recorded'}
# ssc_subtype: {'study_code': 'reg_id'}
# mrss: {'reg_id': 'reg_id', 'date': 'date_recorded'}
# lab_report: {'reg_id': 'reg_id', 'order_date': 'date_recorded'}
# skin_biopsies: {'case_number': 'reg_id', 'biopsy_date': 'date_recorded'}
# libraries: {'reg_id': 'reg_id', 'processing_date': 'date_recorded'}
# vitals: {'reg_id': 'reg_id', 'date': 'date_recorded'}
# pft: {'case_number': 'reg_id', 'pft_dts': 'date_recorded'}
# demographics: {'case_number': 'reg_id'}
# bal: {'reg_id': 'reg_id', 'procedure_date': 'date_recorded'}

# %%
# Step 5: Pivot selected long-format tables into wide format

# Retrieve tables from the datasets dictionary
pft = datasets["pft"].copy()
vitals = datasets["vitals"].copy()
lab_report = datasets["lab_report"].copy()

# ------------------------------------------------------------
# 1. Pulmonary Function Tests (PFT)

pft_id_col = find_id_col(pft)
pft_date_col = find_date_col(pft, extra_candidates=["pft_dts"])

pft_wide = (
    pft.pivot_table(
        index=["reg_id", "date_recorded"],
        columns="name",
        values="ord_value",
        aggfunc="first"
    )
    .reset_index()
)
pft_wide = clean_columns(pft_wide)

# ------------------------------------------------------------
# 2. Vitals

vitals_id_col = find_id_col(vitals)
vitals_date_col = find_date_col(vitals)

vitals_wide = (
    vitals.pivot_table(
        index=["reg_id", "date_recorded"],
        columns="vital_type_name_category",
        values="vital_value",
        aggfunc="first"
    )
    .reset_index()
)
vitals_wide = clean_columns(vitals_wide)

# ------------------------------------------------------------
# 3. Lab Reports

lab_report["value"] = pd.to_numeric(
    lab_report["value"],
    errors="coerce"
)

lab_report_wide = (
    lab_report.pivot_table(
        index=["reg_id", "date_recorded"],
        columns="component_name",
        values="value",
        aggfunc="first"
    )
    .reset_index()
)
lab_report_wide = clean_columns(lab_report_wide)

# %%
lab_report_wide
# Out:
# component_name        reg_id date_recorded  absolute_basophils  \
# 0               subject_2005    2024-01-06                 NaN
# 1               subject_2005    2024-04-29                 NaN
# 2               subject_2005    2024-08-23                 NaN
# 3               subject_2005    2024-08-31                 NaN
# 4               subject_2009    2020-07-27                 NaN
# ...                      ...           ...                 ...
# 3259            subject_8977    2021-01-05                0.02
# 3260            subject_8977    2021-10-12                 NaN
# 3261            subject_8985    2018-10-30                 NaN
# 3262            subject_8989    2020-03-06                 NaN
# 3263            subject_8994    2021-08-23                 NaN
#
# component_name  absolute_eosinophils  absolute_lymphocytes  absolute_monocyte  \
# 0                               0.16                  0.75               0.48
# 1                                NaN                  2.15               0.54
# 2                                NaN                  1.13                NaN
# 3                               0.00                  1.72                NaN
# 4                                NaN                  1.56               0.37
# ...                              ...                   ...                ...
# 3259                            0.00                  1.46               0.88
# 3260                             NaN                  2.22                NaN
# 3261                            0.28                  2.48               0.75
# 3262                            0.10                  0.98               0.34
# 3263                            0.02                   NaN                NaN
#
# component_name  basophils  eosinophils  hematocrit  hemoglobin  ...   mch  \
# 0                     NaN          NaN         NaN        12.8  ...   NaN
# 1                     NaN          NaN        42.1        13.8  ...   NaN
# 2                     NaN          NaN        31.8        10.7  ...   NaN
# 3                     NaN          NaN        35.0        11.9  ...   NaN
# 4                     NaN          3.0         NaN         NaN  ...  29.0
# ...                   ...          ...         ...         ...  ...   ...
# 3259                  0.4          NaN         NaN        11.6  ...  27.8
# 3260                  0.9          NaN         NaN        12.7  ...  32.5
# 3261                  1.1          NaN        37.4        13.1  ...   NaN
# 3262                  0.9          1.9        43.1        14.4  ...  28.9
# 3263                  0.8          0.5         NaN        13.4  ...  27.7
#
# component_name  mchc   mcv  monocytes_body_fluid  neutrophils  \
# 0                NaN  82.3                   NaN          NaN
# 1                NaN   NaN                   NaN         54.2
# 2                NaN   NaN                   NaN          NaN
# 3                NaN  94.0                   NaN         67.3
# 4               31.9  95.2                   NaN          NaN
# ...              ...   ...                   ...          ...
# 3259            33.8  91.2                   NaN          NaN
# 3260            32.5  85.9                   NaN          NaN
# 3261             NaN   NaN                   9.9         49.9
# 3262             NaN  94.0                   NaN          NaN
# 3263             NaN  90.6                   NaN          NaN
#
# component_name  nm_bkr_absolute_neutrophil  platelet_count   rbc   rdw  wbc
# 0                                      NaN           241.0   NaN  15.6  5.8
# 1                                     4.14           330.0   NaN  16.3  7.6
# 2                                      NaN           278.0   NaN   NaN  6.3
# 3                                     6.33           298.0   NaN  16.0  9.4
# 4                                     3.21             NaN   NaN   NaN  5.7
# ...                                    ...             ...   ...   ...  ...
# 3259                                   NaN           375.0   NaN   NaN  9.8
# 3260                                   NaN           375.0   NaN   NaN  7.4
# 3261                                   NaN           331.0   NaN  14.5  7.6
# 3262                                  3.82           294.0  5.84  16.0  NaN
# 3263                                   NaN           113.0  5.77   NaN  4.8
#
# [3264 rows x 21 columns]

# %%
# Step 6: Fix mixed units in demographics height

demographics = datasets["demographics"]
demographics["height_was_cm"] = demographics["height"].apply(lambda h: bool(pd.notna(h) and h >= 100))
demographics["height"] = demographics["height"].apply(
    lambda h: round(h / 2.54, 1) if pd.notna(h) and h >= 100 else h
)
print(f"Converted {int(demographics['height_was_cm'].sum())} height values from cm to inches.")
print(f"New height range: {demographics['height'].min()} - {demographics['height'].max()}")
# Out:
# Converted 265 height values from cm to inches.
# New height range: 54.7 - 78.5

# %%
# Step 6: Summary of pivoted tables
from IPython.display import display, Markdown

pivoted_tables = {
    "PFT": pft_wide,
    "Vitals": vitals_wide,
    "Lab Reports": lab_report_wide
}
for name, df in pivoted_tables.items():

    print("=" * 80)
    print(f"{name} Dataset")
    print(f"Rows: {df.shape[0]:,}")
    print(f"Columns: {df.shape[1]}")

    # Create quality summary table
    summary = pd.DataFrame({
        "Column": df.columns,
        "Data Type": df.dtypes.astype(str).values,
        "Missing Values": df.isna().sum().values,
        "Missing (%)": (
            (df.isna().mean() * 100)
            .round(2)
            .values
        ),
        "Duplicate Values": [
            df[col].duplicated().sum()
            for col in df.columns
        ],
        "Duplicate (%)": [
            round(
                (df[col].duplicated().sum() / len(df)) * 100,
                2
            )
            for col in df.columns
        ]
    })

    display(summary.style.hide(axis="index"))
# Out:
# ================================================================================
# PFT Dataset
# Rows: 1,723
# Columns: 5
# <style type="text/css">
# </style>
# <table id="T_087b7">
#   <thead>
#     <tr>
#       <th id="T_087b7_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_087b7_level0_col1" class="col_heading level0 col1" >Data Type</th>
#       <th id="T_087b7_level0_col2" class="col_heading level0 col2" >Missing Values</th>
#       <th id="T_087b7_level0_col3" class="col_heading level0 col3" >Missing (%)</th>
#       <th id="T_087b7_level0_col4" class="col_heading level0 col4" >Duplicate Values</th>
#       <th id="T_087b7_level0_col5" class="col_heading level0 col5" >Duplicate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_087b7_row0_col0" class="data row0 col0" >reg_id</td>
#       <td id="T_087b7_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_087b7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_087b7_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_087b7_row0_col4" class="data row0 col4" >549</td>
#       <td id="T_087b7_row0_col5" class="data row0 col5" >31.860000</td>
#     </tr>
#     <tr>
#       <td id="T_087b7_row1_col0" class="data row1 col0" >date_recorded</td>
#       <td id="T_087b7_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_087b7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_087b7_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_087b7_row1_col4" class="data row1 col4" >515</td>
#       <td id="T_087b7_row1_col5" class="data row1 col5" >29.890000</td>
#     </tr>
#     <tr>
#       <td id="T_087b7_row2_col0" class="data row2 col0" >dlco_sb</td>
#       <td id="T_087b7_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_087b7_row2_col2" class="data row2 col2" >894</td>
#       <td id="T_087b7_row2_col3" class="data row2 col3" >51.890000</td>
#       <td id="T_087b7_row2_col4" class="data row2 col4" >1295</td>
#       <td id="T_087b7_row2_col5" class="data row2 col5" >75.160000</td>
#     </tr>
#     <tr>
#       <td id="T_087b7_row3_col0" class="data row3 col0" >fev1</td>
#       <td id="T_087b7_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_087b7_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_087b7_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_087b7_row3_col4" class="data row3 col4" >1132</td>
#       <td id="T_087b7_row3_col5" class="data row3 col5" >65.700000</td>
#     </tr>
#     <tr>
#       <td id="T_087b7_row4_col0" class="data row4 col0" >fvc</td>
#       <td id="T_087b7_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_087b7_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_087b7_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_087b7_row4_col4" class="data row4 col4" >1113</td>
#       <td id="T_087b7_row4_col5" class="data row4 col5" >64.600000</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Vitals Dataset
# Rows: 9,131
# Columns: 7
# <style type="text/css">
# </style>
# <table id="T_5a3c9">
#   <thead>
#     <tr>
#       <th id="T_5a3c9_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_5a3c9_level0_col1" class="col_heading level0 col1" >Data Type</th>
#       <th id="T_5a3c9_level0_col2" class="col_heading level0 col2" >Missing Values</th>
#       <th id="T_5a3c9_level0_col3" class="col_heading level0 col3" >Missing (%)</th>
#       <th id="T_5a3c9_level0_col4" class="col_heading level0 col4" >Duplicate Values</th>
#       <th id="T_5a3c9_level0_col5" class="col_heading level0 col5" >Duplicate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5a3c9_row0_col0" class="data row0 col0" >reg_id</td>
#       <td id="T_5a3c9_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_5a3c9_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_5a3c9_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_5a3c9_row0_col4" class="data row0 col4" >7628</td>
#       <td id="T_5a3c9_row0_col5" class="data row0 col5" >83.540000</td>
#     </tr>
#     <tr>
#       <td id="T_5a3c9_row1_col0" class="data row1 col0" >date_recorded</td>
#       <td id="T_5a3c9_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_5a3c9_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_5a3c9_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_5a3c9_row1_col4" class="data row1 col4" >6084</td>
#       <td id="T_5a3c9_row1_col5" class="data row1 col5" >66.630000</td>
#     </tr>
#     <tr>
#       <td id="T_5a3c9_row2_col0" class="data row2 col0" >bmi</td>
#       <td id="T_5a3c9_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_5a3c9_row2_col2" class="data row2 col2" >1354</td>
#       <td id="T_5a3c9_row2_col3" class="data row2 col3" >14.830000</td>
#       <td id="T_5a3c9_row2_col4" class="data row2 col4" >8833</td>
#       <td id="T_5a3c9_row2_col5" class="data row2 col5" >96.740000</td>
#     </tr>
#     <tr>
#       <td id="T_5a3c9_row3_col0" class="data row3 col0" >bp_diastolic</td>
#       <td id="T_5a3c9_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_5a3c9_row3_col2" class="data row3 col2" >1283</td>
#       <td id="T_5a3c9_row3_col3" class="data row3 col3" >14.050000</td>
#       <td id="T_5a3c9_row3_col4" class="data row3 col4" >9085</td>
#       <td id="T_5a3c9_row3_col5" class="data row3 col5" >99.500000</td>
#     </tr>
#     <tr>
#       <td id="T_5a3c9_row4_col0" class="data row4 col0" >bp_systolic</td>
#       <td id="T_5a3c9_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_5a3c9_row4_col2" class="data row4 col2" >1283</td>
#       <td id="T_5a3c9_row4_col3" class="data row4 col3" >14.050000</td>
#       <td id="T_5a3c9_row4_col4" class="data row4 col4" >9065</td>
#       <td id="T_5a3c9_row4_col5" class="data row4 col5" >99.280000</td>
#     </tr>
#     <tr>
#       <td id="T_5a3c9_row5_col0" class="data row5 col0" >pulse</td>
#       <td id="T_5a3c9_row5_col1" class="data row5 col1" >float64</td>
#       <td id="T_5a3c9_row5_col2" class="data row5 col2" >750</td>
#       <td id="T_5a3c9_row5_col3" class="data row5 col3" >8.210000</td>
#       <td id="T_5a3c9_row5_col4" class="data row5 col4" >9071</td>
#       <td id="T_5a3c9_row5_col5" class="data row5 col5" >99.340000</td>
#     </tr>
#     <tr>
#       <td id="T_5a3c9_row6_col0" class="data row6 col0" >weight_in_pound</td>
#       <td id="T_5a3c9_row6_col1" class="data row6 col1" >float64</td>
#       <td id="T_5a3c9_row6_col2" class="data row6 col2" >735</td>
#       <td id="T_5a3c9_row6_col3" class="data row6 col3" >8.050000</td>
#       <td id="T_5a3c9_row6_col4" class="data row6 col4" >8000</td>
#       <td id="T_5a3c9_row6_col5" class="data row6 col5" >87.610000</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Lab Reports Dataset
# Rows: 3,264
# Columns: 21
# <style type="text/css">
# </style>
# <table id="T_4df7f">
#   <thead>
#     <tr>
#       <th id="T_4df7f_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_4df7f_level0_col1" class="col_heading level0 col1" >Data Type</th>
#       <th id="T_4df7f_level0_col2" class="col_heading level0 col2" >Missing Values</th>
#       <th id="T_4df7f_level0_col3" class="col_heading level0 col3" >Missing (%)</th>
#       <th id="T_4df7f_level0_col4" class="col_heading level0 col4" >Duplicate Values</th>
#       <th id="T_4df7f_level0_col5" class="col_heading level0 col5" >Duplicate (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4df7f_row0_col0" class="data row0 col0" >reg_id</td>
#       <td id="T_4df7f_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_4df7f_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_4df7f_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_4df7f_row0_col4" class="data row0 col4" >1951</td>
#       <td id="T_4df7f_row0_col5" class="data row0 col5" >59.770000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row1_col0" class="data row1 col0" >date_recorded</td>
#       <td id="T_4df7f_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_4df7f_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_4df7f_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_4df7f_row1_col4" class="data row1 col4" >1247</td>
#       <td id="T_4df7f_row1_col5" class="data row1 col5" >38.200000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row2_col0" class="data row2 col0" >absolute_basophils</td>
#       <td id="T_4df7f_row2_col1" class="data row2 col1" >float64</td>
#       <td id="T_4df7f_row2_col2" class="data row2 col2" >1907</td>
#       <td id="T_4df7f_row2_col3" class="data row2 col3" >58.430000</td>
#       <td id="T_4df7f_row2_col4" class="data row2 col4" >3248</td>
#       <td id="T_4df7f_row2_col5" class="data row2 col5" >99.510000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row3_col0" class="data row3 col0" >absolute_eosinophils</td>
#       <td id="T_4df7f_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_4df7f_row3_col2" class="data row3 col2" >1873</td>
#       <td id="T_4df7f_row3_col3" class="data row3 col3" >57.380000</td>
#       <td id="T_4df7f_row3_col4" class="data row3 col4" >3201</td>
#       <td id="T_4df7f_row3_col5" class="data row3 col5" >98.070000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row4_col0" class="data row4 col0" >absolute_lymphocytes</td>
#       <td id="T_4df7f_row4_col1" class="data row4 col1" >float64</td>
#       <td id="T_4df7f_row4_col2" class="data row4 col2" >1942</td>
#       <td id="T_4df7f_row4_col3" class="data row4 col3" >59.500000</td>
#       <td id="T_4df7f_row4_col4" class="data row4 col4" >2949</td>
#       <td id="T_4df7f_row4_col5" class="data row4 col5" >90.350000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row5_col0" class="data row5 col0" >absolute_monocyte</td>
#       <td id="T_4df7f_row5_col1" class="data row5 col1" >float64</td>
#       <td id="T_4df7f_row5_col2" class="data row5 col2" >1865</td>
#       <td id="T_4df7f_row5_col3" class="data row5 col3" >57.140000</td>
#       <td id="T_4df7f_row5_col4" class="data row5 col4" >3152</td>
#       <td id="T_4df7f_row5_col5" class="data row5 col5" >96.570000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row6_col0" class="data row6 col0" >basophils</td>
#       <td id="T_4df7f_row6_col1" class="data row6 col1" >float64</td>
#       <td id="T_4df7f_row6_col2" class="data row6 col2" >1902</td>
#       <td id="T_4df7f_row6_col3" class="data row6 col3" >58.270000</td>
#       <td id="T_4df7f_row6_col4" class="data row6 col4" >3246</td>
#       <td id="T_4df7f_row6_col5" class="data row6 col5" >99.450000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row7_col0" class="data row7 col0" >eosinophils</td>
#       <td id="T_4df7f_row7_col1" class="data row7 col1" >float64</td>
#       <td id="T_4df7f_row7_col2" class="data row7 col2" >1898</td>
#       <td id="T_4df7f_row7_col3" class="data row7 col3" >58.150000</td>
#       <td id="T_4df7f_row7_col4" class="data row7 col4" >3197</td>
#       <td id="T_4df7f_row7_col5" class="data row7 col5" >97.950000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row8_col0" class="data row8 col0" >hematocrit</td>
#       <td id="T_4df7f_row8_col1" class="data row8 col1" >float64</td>
#       <td id="T_4df7f_row8_col2" class="data row8 col2" >1350</td>
#       <td id="T_4df7f_row8_col3" class="data row8 col3" >41.360000</td>
#       <td id="T_4df7f_row8_col4" class="data row8 col4" >3029</td>
#       <td id="T_4df7f_row8_col5" class="data row8 col5" >92.800000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row9_col0" class="data row9 col0" >hemoglobin</td>
#       <td id="T_4df7f_row9_col1" class="data row9 col1" >float64</td>
#       <td id="T_4df7f_row9_col2" class="data row9 col2" >1349</td>
#       <td id="T_4df7f_row9_col3" class="data row9 col3" >41.330000</td>
#       <td id="T_4df7f_row9_col4" class="data row9 col4" >3182</td>
#       <td id="T_4df7f_row9_col5" class="data row9 col5" >97.490000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row10_col0" class="data row10 col0" >lymphocytes</td>
#       <td id="T_4df7f_row10_col1" class="data row10 col1" >float64</td>
#       <td id="T_4df7f_row10_col2" class="data row10 col2" >1655</td>
#       <td id="T_4df7f_row10_col3" class="data row10 col3" >50.700000</td>
#       <td id="T_4df7f_row10_col4" class="data row10 col4" >2905</td>
#       <td id="T_4df7f_row10_col5" class="data row10 col5" >89.000000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row11_col0" class="data row11 col0" >mch</td>
#       <td id="T_4df7f_row11_col1" class="data row11 col1" >float64</td>
#       <td id="T_4df7f_row11_col2" class="data row11 col2" >1220</td>
#       <td id="T_4df7f_row11_col3" class="data row11 col3" >37.380000</td>
#       <td id="T_4df7f_row11_col4" class="data row11 col4" >3162</td>
#       <td id="T_4df7f_row11_col5" class="data row11 col5" >96.880000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row12_col0" class="data row12 col0" >mchc</td>
#       <td id="T_4df7f_row12_col1" class="data row12 col1" >float64</td>
#       <td id="T_4df7f_row12_col2" class="data row12 col2" >1391</td>
#       <td id="T_4df7f_row12_col3" class="data row12 col3" >42.620000</td>
#       <td id="T_4df7f_row12_col4" class="data row12 col4" >3200</td>
#       <td id="T_4df7f_row12_col5" class="data row12 col5" >98.040000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row13_col0" class="data row13 col0" >mcv</td>
#       <td id="T_4df7f_row13_col1" class="data row13 col1" >float64</td>
#       <td id="T_4df7f_row13_col2" class="data row13 col2" >1376</td>
#       <td id="T_4df7f_row13_col3" class="data row13 col3" >42.160000</td>
#       <td id="T_4df7f_row13_col4" class="data row13 col4" >3023</td>
#       <td id="T_4df7f_row13_col5" class="data row13 col5" >92.620000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row14_col0" class="data row14 col0" >monocytes_body_fluid</td>
#       <td id="T_4df7f_row14_col1" class="data row14 col1" >float64</td>
#       <td id="T_4df7f_row14_col2" class="data row14 col2" >2445</td>
#       <td id="T_4df7f_row14_col3" class="data row14 col3" >74.910000</td>
#       <td id="T_4df7f_row14_col4" class="data row14 col4" >3158</td>
#       <td id="T_4df7f_row14_col5" class="data row14 col5" >96.750000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row15_col0" class="data row15 col0" >neutrophils</td>
#       <td id="T_4df7f_row15_col1" class="data row15 col1" >float64</td>
#       <td id="T_4df7f_row15_col2" class="data row15 col2" >1678</td>
#       <td id="T_4df7f_row15_col3" class="data row15 col3" >51.410000</td>
#       <td id="T_4df7f_row15_col4" class="data row15 col4" >2853</td>
#       <td id="T_4df7f_row15_col5" class="data row15 col5" >87.410000</td>
#     </tr>
#     <tr>
#       <td id="T_4df7f_row16_col0" class="data row16 col0" >nm_bkr_absolute_neutrophil</td>
#       <td id="T_4df7f_row16_col1" class="data row16 col1" >float64</td>
#       <td id="T_4df7f_row16_col2" class="data row16 col2" >2479</td>
#       <td id="

# %%
# Step 7: Generate Relationship Summary Table

relationships = []

tables = list(datasets.keys())

for i in range(len(tables)):
    for j in range(i + 1, len(tables)):

        table1 = tables[i]
        table2 = tables[j]

        df1 = datasets[table1]
        df2 = datasets[table2]

        # Find common columns
        common_cols = set(df1.columns).intersection(df2.columns)

        for col in common_cols:

            # Focus on identifier columns
            if (
                "id" in col.lower()
                or "case" in col.lower()
                or "number" in col.lower()
            ):

                # Determine relationship type
                table1_unique = df1[col].is_unique
                table2_unique = df2[col].is_unique

                if table1_unique and table2_unique:
                    relationship = "One-to-One"

                elif table1_unique and not table2_unique:
                    relationship = "One-to-Many"

                elif not table1_unique and table2_unique:
                    relationship = "One-to-Many"

                else:
                    relationship = "Many-to-Many"

                relationships.append({
                    "Table 1": table1,
                    "Table 2": table2,
                    "Relationship Key": col,
                    "Relationship Type": relationship
                })

# Print relatiosnhip summary
# Create summary dataframe
relationship_summary = pd.DataFrame(relationships)

# Remove duplicate relationships if any
relationship_summary = relationship_summary.drop_duplicates()

display(relationship_summary)
# Out:
#           Table 1        Table 2 Relationship Key Relationship Type
# 0     medications     antibodies           reg_id      Many-to-Many
# 1     medications    ssc_subtype           reg_id       One-to-Many
# 2     medications           mrss           reg_id      Many-to-Many
# 3     medications     lab_report           reg_id      Many-to-Many
# 4     medications  skin_biopsies           reg_id      Many-to-Many
# 5     medications      libraries           reg_id      Many-to-Many
# 6     medications         vitals           reg_id      Many-to-Many
# 7     medications            pft           reg_id      Many-to-Many
# 8     medications   demographics           reg_id       One-to-Many
# 9     medications            bal           reg_id      Many-to-Many
# 10     antibodies    ssc_subtype           reg_id       One-to-Many
# 11     antibodies           mrss           reg_id      Many-to-Many
# 12     antibodies     lab_report           reg_id      Many-to-Many
# 13     antibodies  skin_biopsies           reg_id      Many-to-Many
# 14     antibodies      libraries           reg_id      Many-to-Many
# 15     antibodies         vitals           reg_id      Many-to-Many
# 16     antibodies            pft           reg_id      Many-to-Many
# 17     antibodies   demographics           reg_id       One-to-Many
# 18     antibodies            bal           reg_id      Many-to-Many
# 19    ssc_subtype           mrss           reg_id       One-to-Many
# 20    ssc_subtype     lab_report           reg_id       One-to-Many
# 21    ssc_subtype  skin_biopsies           reg_id       One-to-Many
# 22    ssc_subtype      libraries           reg_id       One-to-Many
# 23    ssc_subtype         vitals           reg_id       One-to-Many
# 24    ssc_subtype            pft           reg_id       One-to-Many
# 25    ssc_subtype   demographics           reg_id        One-to-One
# 26    ssc_subtype            bal           reg_id       One-to-Many
# 27           mrss     lab_report           reg_id      Many-to-Many
# 28           mrss  skin_biopsies           reg_id      Many-to-Many
# 29           mrss      libraries           reg_id      Many-to-Many
# 30           mrss         vitals           reg_id      Many-to-Many
# 31           mrss            pft           reg_id      Many-to-Many
# 32           mrss   demographics           reg_id       One-to-Many
# 33           mrss            bal           reg_id      Many-to-Many
# 34     lab_report  skin_biopsies           reg_id      Many-to-Many
# 35     lab_report      libraries           reg_id      Many-to-Many
# 36     lab_report         vitals           reg_id      Many-to-Many
# 37     lab_report            pft           reg_id      Many-to-Many
# 38     lab_report   demographics           reg_id       One-to-Many
# 39     lab_report            bal           reg_id      Many-to-Many
# 40  skin_biopsies      libraries           reg_id      Many-to-Many
# 41  skin_biopsies         vitals           reg_id      Many-to-Many
# 42  skin_biopsies            pft           reg_id      Many-to-Many
# 43  skin_biopsies   demographics           reg_id       One-to-Many
# 44  skin_biopsies            bal           reg_id      Many-to-Many
# 45      libraries         vitals           reg_id      Many-to-Many
# 46      libraries            pft           reg_id      Many-to-Many
# 47      libraries   demographics           reg_id       One-to-Many
# 48      libraries            bal           reg_id      Many-to-Many
# 49         vitals            pft           reg_id      Many-to-Many
# 50         vitals   demographics           reg_id       One-to-Many
# 51         vitals            bal           reg_id      Many-to-Many
# 52            pft   demographics           reg_id       One-to-Many
# 53            pft            bal           reg_id      Many-to-Many
# 54   demographics            bal           reg_id       One-to-Many

# %%
# !ls {output_folder}
# Out:
# Data_QC.ipynb data_v3       data_v3.zip

# %%
# Step 8: Export cleaned datasets
output_folder.mkdir(exist_ok=True)

folder = "cleaned_datasets"
full_path = os.path.join(output_folder, folder)

os.mkdir(full_path)

# Save original datasets
for name, df in datasets.items():
    print(name)
    df.to_csv(f"{full_path}/{name}.csv", index=False)

# Save pivoted datasets
pft_wide.to_csv(f"{full_path}/pft_wide.csv", index=False)
vitals_wide.to_csv(f"{full_path}/vitals_wide.csv", index=False)
lab_report_wide.to_csv(f"{full_path}/lab_report_wide.csv", index=False)

print("All datasets saved successfully.")
# Out:
# medications
# antibodies
# ssc_subtype
# mrss
# lab_report
# skin_biopsies
# libraries
# vitals
# pft
# demographics
# bal
# All datasets saved successfully.

# %%
# Step 9: Store new cleaned dataset
# Path to cleaned dataset folder
# cleaned_folder = Path("/Users/gauri1399/Desktop/Northwestern/Final/cleaned_datasets")



# Dictionary to store cleaned datasets


cleaned_datasets = {}

# Load all CSV files
for file in Path(full_path).glob("*.csv"):
    print(file)

    df = pd.read_csv(file)

    # Store using filename (without .csv) as key
    cleaned_datasets[file.stem] = df

print("Loaded datasets:")
print(cleaned_datasets.keys())
# Out:
# cleaned_datasets/medications.csv
# cleaned_datasets/antibodies.csv
# cleaned_datasets/ssc_subtype.csv
# cleaned_datasets/mrss.csv
# cleaned_datasets/vitals_wide.csv
# cleaned_datasets/lab_report.csv
# cleaned_datasets/pft_wide.csv
# cleaned_datasets/skin_biopsies.csv
# cleaned_datasets/libraries.csv
# cleaned_datasets/lab_report_wide.csv
# cleaned_datasets/vitals.csv
# cleaned_datasets/pft.csv
# cleaned_datasets/demographics.csv
# cleaned_datasets/bal.csv
# Loaded datasets:
# dict_keys(['medications', 'antibodies', 'ssc_subtype', 'mrss', 'vitals_wide', 'lab_report', 'pft_wide', 'skin_biopsies', 'libraries', 'lab_report_wide', 'vitals', 'pft', 'demographics', 'bal'])

# %%
# Step 10: Assign cleaned datasets to individual dataframes
demographics = cleaned_datasets["demographics"]
antibodies = cleaned_datasets["antibodies"]
mrss = cleaned_datasets["mrss"]
bal = cleaned_datasets["bal"]
medications = cleaned_datasets["medications"]

pft_wide = cleaned_datasets["pft_wide"]
vitals_wide = cleaned_datasets["vitals_wide"]
lab_report_wide = cleaned_datasets["lab_report_wide"]

ssc_subtype = cleaned_datasets["ssc_subtype"]
skin_biopsies = cleaned_datasets["skin_biopsies"]
libraries = cleaned_datasets["libraries"]

# %%
# Step 3: Plot graphs
# 1. Demographics

# Plot 1: Race Distribution
plt.figure(figsize=(8,5))
sns.histplot(demographics["races"], bins=20, kde=False)
plt.title("Race Distribution in the SSc Cohort")
plt.xlabel("Race")
plt.ylabel("Number of Patients")
plt.show()

#========================================================================

# Plot 2: Age distribution
demographics = cleaned_datasets["demographics"].copy()

# Convert birth date
demographics["birth_date"] = pd.to_datetime(
    demographics["birth_date"],
    errors="coerce"
)

# Calculate age
today = pd.Timestamp.today()
demographics["age"] = (
    (today - demographics["birth_date"]).dt.days / 365.25
).astype(int)

plt.figure(figsize=(8,5))

sns.histplot(
    demographics["age"],
    bins=15,
    kde=True
)

plt.title("Age Distribution")
plt.xlabel("Age (Years)")
plt.ylabel("Number of Patients")

plt.show()

#========================================================================

# Plot 3: Gender distribution
plt.figure(figsize=(6,5))
sns.countplot(
    data=demographics,
    x="gender",
    palette={
    "Female": "#FF69B4",  # Pink
    "Male": "#4F81BD"     # Blue
}
)

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Patient Count")

plt.show()
# Out:
# /var/folders/5l/m44zbc8s1zj27rpr7mstfkqh0000gn/T/ipykernel_97538/2944475915.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
# 2. Merge demographics with SSc subtype information
ssc_demo = demographics.merge(
    ssc_subtype,
    on="reg_id",
    how="left"
)

# Create gender count table
ssc_gender_pct = (
    ssc_demo
    .groupby(["ssc_subtype", "gender"])
    .size()
    .reset_index(name="count")
)

# Calculate percentage within each SSc subtype
ssc_gender_pct["percentage"] = (
    ssc_gender_pct.groupby("ssc_subtype")["count"]
    .transform(lambda x: x / x.sum() * 100)
)

# Plot 4
plt.figure(figsize=(8,5))

ax = sns.barplot(
    data=ssc_gender_pct,
    x="ssc_subtype",
    y="percentage",
    hue="gender"
)

# Add percentage labels
for container in ax.containers:
    ax.bar_label(
        container,
        fmt="%.1f%%",
        padding=3
    )

plt.title("Gender Distribution Within SSc Subtypes")
plt.xlabel("SSc Subtype")
plt.ylabel("Percentage of Patients (%)")

plt.ylim(0, 100)
plt.tight_layout()

plt.show()

# %%
# 3. Correlation between PF measures

# Plot 5
plt.figure(figsize=(6,5))

corr = pft_wide[
    ["dlco_sb", "fev1", "fvc"]
].corr()

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Between Pulmonary Function Measures")

plt.show()
